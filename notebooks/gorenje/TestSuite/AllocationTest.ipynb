# %% [markdown]
# # SysML v2 Test Suite
#
# This can notebook can be cleared using menu `Edit --> Clear All Outputs` and then all cells can be
# run using menu `Run --> Run All Cells`.
#
# **WARNING**: This file is generated, all modifications here will be ignored.

# %% [markdown]
# ## File: ../../sysml/src/examples/Simple Tests/AllocationTest.sysml

# %%
package AllocationTest {
	part def Logical {
		part component;
	}
	
	part def Physical {
		part assembly {
			part element;
		}
	}
	
	part l : Logical {
		part :>> component;
	}
	part p : Physical {
		part :>> assembly {
			part :>> element;
		}
	}
	
	allocation def A;
	
	allocation def Logical_to_Physical :> A {
		end logical : Logical;
		end physical : Physical;
	}
	
	allocation allocation1 : Logical_to_Physical allocate l to p;	
	allocation allocation2 : Logical_to_Physical allocate (
		logical ::> l,
		physical ::> p
	);

	allocate l.component to p.assembly.element;
}
# Out:
# Package AllocationTest (b672f578-d55c-46c8-8e8f-a07b6a413180)

# %%
%viz --style="COMPTREE" --view="Default" "AllocationTest"

# %%
%viz --style="COMPTREE" --view="Tree" "AllocationTest"

# %%
%viz --style="COMPTREE" --view="State" "AllocationTest"

# %%
%viz --style="COMPTREE" --view="Interconnection" "AllocationTest"

# %%
%viz --style="COMPTREE" --view="Action" "AllocationTest"

# %%
%viz --style="COMPTREE" --view="Sequence" "AllocationTest"

# %%
%viz --style="COMPTREE" --view="MIXED" "AllocationTest"

# %%
%viz --style="POLYLINE" --view="Default" "AllocationTest"

# %%
%viz --style="POLYLINE" --view="Tree" "AllocationTest"

# %%
%viz --style="POLYLINE" --view="State" "AllocationTest"

# %%
%viz --style="POLYLINE" --view="Interconnection" "AllocationTest"

# %%
%viz --style="POLYLINE" --view="Action" "AllocationTest"

# %%
%viz --style="POLYLINE" --view="Sequence" "AllocationTest"

# %%
%viz --style="POLYLINE" --view="MIXED" "AllocationTest"

# %%
%viz --style="LR" --view="Default" "AllocationTest"

# %%
%viz --style="LR" --view="Tree" "AllocationTest"

# %%
%viz --style="LR" --view="State" "AllocationTest"

# %%
%viz --style="LR" --view="Interconnection" "AllocationTest"

# %%
%viz --style="LR" --view="Action" "AllocationTest"

# %%
%viz --style="LR" --view="Sequence" "AllocationTest"

# %%
%viz --style="LR" --view="MIXED" "AllocationTest"

# %%
%viz --style="STDCOLOR" --view="Default" "AllocationTest"

# %%
%viz --style="STDCOLOR" --view="Tree" "AllocationTest"

# %%
%viz --style="STDCOLOR" --view="State" "AllocationTest"

# %%
%viz --style="STDCOLOR" --view="Interconnection" "AllocationTest"

# %%
%viz --style="STDCOLOR" --view="Action" "AllocationTest"

# %%
%viz --style="STDCOLOR" --view="Sequence" "AllocationTest"

# %%
%viz --style="STDCOLOR" --view="MIXED" "AllocationTest"

# %%
%viz --style="PLANTUML" --view="Default" "AllocationTest"

# %%
%viz --style="PLANTUML" --view="Tree" "AllocationTest"

# %%
%viz --style="PLANTUML" --view="State" "AllocationTest"

# %%
%viz --style="PLANTUML" --view="Interconnection" "AllocationTest"

# %%
%viz --style="PLANTUML" --view="Action" "AllocationTest"

# %%
%viz --style="PLANTUML" --view="Sequence" "AllocationTest"

# %%
%viz --style="PLANTUML" --view="MIXED" "AllocationTest"

# %%
%viz --style="DEFAULT" --view="Default" "AllocationTest"

# %%
%viz --style="DEFAULT" --view="Tree" "AllocationTest"

# %%
%viz --style="DEFAULT" --view="State" "AllocationTest"

# %%
%viz --style="DEFAULT" --view="Interconnection" "AllocationTest"

# %%
%viz --style="DEFAULT" --view="Action" "AllocationTest"

# %%
%viz --style="DEFAULT" --view="Sequence" "AllocationTest"

# %%
%viz --style="DEFAULT" --view="MIXED" "AllocationTest"

# %%
%viz --style="TB" --view="Default" "AllocationTest"

# %%
%viz --style="TB" --view="Tree" "AllocationTest"

# %%
%viz --style="TB" --view="State" "AllocationTest"

# %%
%viz --style="TB" --view="Interconnection" "AllocationTest"

# %%
%viz --style="TB" --view="Action" "AllocationTest"

# %%
%viz --style="TB" --view="Sequence" "AllocationTest"

# %%
%viz --style="TB" --view="MIXED" "AllocationTest"

# %%
%viz --style="ORTHOLINE" --view="Default" "AllocationTest"

# %%
%viz --style="ORTHOLINE" --view="Tree" "AllocationTest"

# %%
%viz --style="ORTHOLINE" --view="State" "AllocationTest"

# %%
%viz --style="ORTHOLINE" --view="Interconnection" "AllocationTest"

# %%
%viz --style="ORTHOLINE" --view="Action" "AllocationTest"

# %%
%viz --style="ORTHOLINE" --view="Sequence" "AllocationTest"

# %%
%viz --style="ORTHOLINE" --view="MIXED" "AllocationTest"
